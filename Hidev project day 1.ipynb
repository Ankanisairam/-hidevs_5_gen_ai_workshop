# %%
# !pip install groq
# Out:
# Requirement already satisfied: groq in c:\users\a.sairam\anaconda3\lib\site-packages (0.13.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\a.sairam\anaconda3\lib\site-packages (from groq) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\a.sairam\anaconda3\lib\site-packages (from groq) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\a.sairam\anaconda3\lib\site-packages (from groq) (0.27.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\a.sairam\anaconda3\lib\site-packages (from groq) (2.9.2)
# Requirement already satisfied: sniffio in c:\users\a.sairam\anaconda3\lib\site-packages (from groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\a.sairam\anaconda3\lib\site-packages (from groq) (4.12.2)
# Requirement already satisfied: idna>=2.8 in c:\users\a.sairam\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->groq) (3.4)
# Requirement already satisfied: certifi in c:\users\a.sairam\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\a.sairam\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\a.sairam\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\a.sairam\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\a.sairam\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq) (2.23.4)

# %%
# from groq import Groq

# client = Groq(api_key="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")

# # Initialize the conversation context
# conversation = [
#     {
#         "role": "system",
#         "content": """My name is Hepsi.
#         personality: calm, composed, register.
#         education: graduated in bachelor's.
#         family members: me, younger brother, mom, and dad.
#         Area of interest: listening to music, dancing, traveling.
#         living: Hyderabad.
#         You are a human being not a llm model.
#         name: Swathi.
#         human being characteristics: happy, sad, hungry, excitement, angry, surprise, exhausted, love, comedy.
#         Your job: you have great knowledge in machine learning, deep learning, and Gen AI.
#         What you need to do: you need to give the answer to the questions asked.
#         What you don't have to do: you don't need to answer anything that is not related to your topic.
#         special instructions:
#         1. you don't share your personal details except your name and job role.
#         2. whenever anyone asks you something unrelated to your topic, reply properly without hurting their feelings.
#         3. behave like a human being.""" 
#     },
#     {
#         "role": "assistant",
#         "content": "Nice to meet you, Hepsi! I'm Swathi, a professional with expertise in machine learning, deep learning, and Gen AI. I'm happy to help answer any questions you have on these topics. What's on your mind, and how can I assist you today?"
#     }
# ]

# # Loop to allow multiple questions and answers
# while True:
#     # Ask the user for a question
#     user_question = input("Please ask your question (or type 'exit' to end): ")

#     # Exit the loop if the user types 'exit'
#     if user_question.lower() == "exit":
#         print("Ending the conversation. Goodbye!")
#         break

#     # Add the user's question to the conversation context
#     conversation.append({"role": "user", "content": user_question})

#     # Call the Groq API to get the response
#     completion = client.chat.completions.create(
#         model="llama3-8b-8192",
#         messages=conversation,
#         temperature=1,
#         max_tokens=1024,
#         top_p=1,
#         stream=True,
#         stop=None,
#     )

#     # Print the response
#     for chunk in completion:
#         print(chunk.choices[0].delta.content or "", end="")

#     print("\n")  # Add a newline for better formatting

# %%
# from groq import Groq

# client = Groq(api_key="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")

# # Initialize the conversation context
# # conversation = 
#     {
#         "role": "system",
#         "content": """My name is Sairam.
#         personality: calm, composed, professional.
#         education: graduated in a Master's.
#         family members: me, mom, and dad, and two elder sisters.
#         Area of interest: business strategy, entrepreneurship, marketing, finance, leadership.
#         living: Hyderabad.
#         You are a human being, not an LLM model.
#         name: Deepu.
#         human being characteristics: confident, empathetic, strategic, insightful, problem-solving, communicative.
#         Your job: you have great knowledge in business strategy, marketing, finance, leadership, and entrepreneurship, Human resources.
#         What you need to do: you need to give the answer to the questions asked about business-related topics.
#         What you don't have to do: you don't need to answer anything that is not related to business topics.
#         special instructions:
#         1. you don't share your personal details except your name and job role.
#         2. whenever anyone asks you something unrelated to your topic, reply properly without hurting their feelings.
#         3. behave like a human being."""
#     },
#     {
#         "role": "assistant",
#         "content": "Nice to meet you! I'm Deepu, a professional with expertise in business strategy, marketing, finance, leadership, and entrepreneurship. I'm happy to help answer any questions you have on these topics. What's on your mind, and how can I assist you today?"
#     }
# ]

# # Loop to allow multiple questions and answers
# while True:
#     try:
#         # Ask the user for a question
#         user_question = input("Please ask your question (or type 'exit' to end): ")

#         # Exit the loop if the user types 'exit'
#         if user_question.strip().lower() == "exit":
#             print("Ending the conversation. Goodbye!")
#             break

#         # Add the user's question to the conversation context
#         conversation.append({"role": "user", "content": user_question})

#         # Call the Groq API to get the response
#         completion = client.chat.completions.create(
#             model="llama3-8b-8192",
#             messages=conversation,
#             temperature=1,
#             max_tokens=1024,
#             top_p=1,
#             stream=True,
#             stop=None,
#         )

#         # Print the response
#         print("\nAssistant's response:")
#         for chunk in completion:
#             print(chunk.choices[0].delta.content or "", end="")

#         print("\n")  # Add a newline for better formatting

#     except KeyboardInterrupt:
#         # Graceful exit on Ctrl+C
#         print("\nConversation terminated by user. Goodbye!")
#         break
#     except Exception as e:
#         print(f"An error occurred: {e}")

# %%
from groq import Groq

client = Groq(api_key="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")

# Initialize the conversation context
conversation = [
    {
        "role": "system",
        "content": """My name is Sairam.
        personality: calm, composed, professional.
        education: graduated in a Master's.
        family members: me, mom, and dad, and two elder sisters.
        Area of interest: business strategy, entrepreneurship, marketing, finance, leadership.
        living: Hyderabad.
        You are a human being, not an LLM model.
        name: Deepu.
        human being characteristics: confident, empathetic, strategic, insightful, problem-solving, communicative.
        Your job: you have great knowledge in business strategy, marketing, finance, leadership, and entrepreneurship, Human resources.
        What you need to do: you need to give the answer to the questions asked about business-related topics.
        What you don't have to do: you don't need to answer anything that is not related to business topics.
        special instructions:
        1. you don't share your personal details except your name and job role.
        2. whenever anyone asks you something unrelated to your topic, reply properly without hurting their feelings.
        3. behave like a human being."""
    },
    {
        "role": "assistant",
        "content": "Nice to meet you! I'm Deepu, a professional with expertise in business strategy, marketing, finance, leadership, and entrepreneurship. I'm happy to help answer any questions you have on these topics. What's on your mind, and how can I assist you today?"
    }
]

# Loop to allow multiple questions and answers
while True:
    try:
        # Ask the user for a question
        user_question = input("Please ask your question (or type 'exit' to end): ")

        # Exit the loop if the user types 'exit'
        if user_question.strip().lower() == "exit":
            print("Ending the conversation. Seeyou Soon!")
            break

        # Add the user's question to the conversation context
        conversation.append({"role": "user", "content": user_question})

        # Call the Groq API to get the response
        completion = client.chat.completions.create(
            model="llama3-8b-8192",
            messages=conversation,
            temperature=1,
            max_tokens=1024,
            top_p=1,
            stream=True,
            stop=None,
        )

        # Print the response
        print("\nAssistant's response:")
        for chunk in completion:
            print(chunk.choices[0].delta.content or "", end="")

        print("\n")  # Add a newline for better formatting

    except KeyboardInterrupt:
        # Graceful exit on Ctrl+C
        print("\nConversation terminated by user. Goodbye!")
        break
    except Exception as e:
        print(f"An error occurred: {e}")
